# %%
import cv2
import os

def extract_frames(video_path, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Open the video file
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Unable to open video file '{video_path}'.")
        return

    # Initialize frame count
    frame_count = 0

    # Read until video is completed
    while True:
        # Read a frame from the video
        ret, frame = cap.read()

        # Break the loop if no frame is read
        if not ret:
            break

        # Save frame as an image
        frame_count += 4
        # Use the video name and frame count to generate unique filenames
        video_name = os.path.splitext(os.path.basename(video_path))[0]  # Get video name without extension
        frame_filename = os.path.join(output_folder, f"{frame_count:04d}.jpg")
        cv2.imwrite(frame_filename, frame)

    # Release the video capture object
    cap.release()

    print(f"Frames extracted from '{video_path}': {frame_count}")

if __name__ == "__main__":
    # Input folder containing videos
    videos_folder = r"videos"

    # Output folder to save frames
    output_folder = "frames"

    # Iterate over each video file in the videos folder
    for video_file in os.listdir(videos_folder):
        if video_file.endswith(".mp4"):  # Assuming all video files are .mp4
            video_path = os.path.join(videos_folder, video_file)

            # Call the function to extract frames from this video
            extract_frames(video_path, output_folder)
# Out:
# Frames extracted from 'videos\video-1.mp4': 528

# %%
import os
import numpy as np
import cv2
from tensorflow.keras.models import load_model

def load_image(image_path, target_size):
    """
    Loads an image from a file, resizes it, and normalizes it.
    """
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, target_size)
    image = image.astype(np.float32) / 255.0  # Normalize pixel values
    return image

def save_image(image, output_path):
    """
    Saves an image to the specified path, converting it back to 8-bit format.
    """
    image = (image * 255).astype(np.uint8)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    cv2.imwrite(output_path, image)

def interpolate_frames(input_folder, output_folder, model, target_size):
    """
    Processes frames in the input folder, interpolates using the model, and saves the results.
    
    Args:
        input_folder: Path to the folder containing input frames.
        output_folder: Path to the folder where output frames will be saved.
        model: Trained TensorFlow model for frame interpolation.
        target_size: Tuple (width, height) to resize frames.
    """
    # Ensure output folder exists
    os.makedirs(output_folder, exist_ok=True)
    
    # Get all frame filenames, sorted numerically
    frame_files = sorted(os.listdir(input_folder), key=lambda x: int(os.path.splitext(x)[0]))
    
    for i in range(0, len(frame_files) - 1, 2):
        # Load the first and second frames
        frame1_path = os.path.join(input_folder, frame_files[i])
        frame2_path = os.path.join(input_folder, frame_files[i + 1])
        
        frame1 = load_image(frame1_path, target_size)
        frame2 = load_image(frame2_path, target_size)
        
        # Predict the middle frame using the model
        frame1_expanded = np.expand_dims(frame1, axis=0)
        frame2_expanded = np.expand_dims(frame2, axis=0)
        middle_frame = model.predict([frame1_expanded, frame2_expanded])[0]
        
        # Save the first and second frames to the output folder
        save_image(frame1, os.path.join(output_folder, frame_files[i]))
        save_image(frame2, os.path.join(output_folder, frame_files[i + 1]))
        
        # Calculate the name for the middle frame
        frame1_number = int(os.path.splitext(frame_files[i])[0])
        frame2_number = int(os.path.splitext(frame_files[i + 1])[0])
        middle_frame_number = (frame1_number + frame2_number) // 2
        middle_frame_name = f"{middle_frame_number:03d}.png"  # Zero-padded name
        
        # Save the middle frame
        save_image(middle_frame, os.path.join(output_folder, middle_frame_name))
        print(f"Processed frames {frame_files[i]} and {frame_files[i + 1]}, saved {middle_frame_name}")

# Load the model
model = load_model("model_colab1.h5", compile=False)
model.compile(optimizer="adam", loss="mse")

# first iteration
input_folder = r"frames"
output_folder = r"outputs"
target_size = (256, 256)  # Resize frames to match the model's input size

# Interpolate frames using the loaded model
interpolate_frames(input_folder, output_folder, model, target_size)

# second iteration

input_folder = r"outputs"
output_folder = r"outputs2"
target_size = (256, 256)  # Resize frames to match the model's input size

# Interpolate frames using the loaded model
interpolate_frames(input_folder, output_folder, model, target_size)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0004.jpg and 0008.jpg, saved 006.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0012.jpg and 0016.jpg, saved 014.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0020.jpg and 0024.jpg, saved 022.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0028.jpg and 0032.jpg, saved 030.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0036.jpg and 0040.jpg, saved 038.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0044.jpg and 0048.jpg, saved 046.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0052.jpg and 0056.jpg, saved 054.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0060.jpg and 0064.jpg, saved 062.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0068.jpg and 0072.jpg, saved 070.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0076.jpg and 0080.jpg, saved 078.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0084.jpg and 0088.jpg, saved 086.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0092.jpg and 0096.jpg, saved 094.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0100.jpg and 0104.jpg, saved 102.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0108.jpg and 0112.jpg, saved 110.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0116.jpg and 0120.jpg, saved 118.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0124.jpg and 0128.jpg, saved 126.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0132.jpg and 0136.jpg, saved 134.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0140.jpg and 0144.jpg, saved 142.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0148.jpg and 0152.jpg, saved 150.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0156.jpg and 0160.jpg, saved 158.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0164.jpg and 0168.jpg, saved 166.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0172.jpg and 0176.jpg, saved 174.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0180.jpg and 0184.jpg, saved 182.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0188.jpg and 0192.jpg, saved 190.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0196.jpg and 0200.jpg, saved 198.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0204.jpg and 0208.jpg, saved 206.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0212.jpg and 0216.jpg, saved 214.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0220.jpg and 0224.jpg, saved 222.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0228.jpg and 0232.jpg, saved 230.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0236.jpg and 0240.jpg, saved 238.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0244.jpg and 0248.jpg, saved 246.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0252.jpg and 0256.jpg, saved 254.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0260.jpg and 0264.jpg, saved 262.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0268.jpg and 0272.jpg, saved 270.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0276.jpg and 0280.jpg, saved 278.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0284.jpg and 0288.jpg, saved 286.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0292.jpg and 0296.jpg, saved 294.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0300.jpg and 0304.jpg, saved 302.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0308.jpg and 0312.jpg, saved 310.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0316.jpg and 0320.jpg, saved 318.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0324.jpg and 0328.jpg, saved 326.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0332.jpg and 0336.jpg, saved 334.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0340.jpg and 0344.jpg, saved 342.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0348.jpg and 0352.jpg, saved 350.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0356.jpg and 0360.jpg, saved 358.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0364.jpg and 0368.jpg, saved 366.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0372.jpg and 0376.jpg, saved 374.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0380.jpg and 0384.jpg, saved 382.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0388.jpg and 0392.jpg, saved 390.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0396.jpg and 0400.jpg, saved 398.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0404.jpg and 0408.jpg, saved 406.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0412.jpg and 0416.jpg, saved 414.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0420.jpg and 0424.jpg, saved 422.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0428.jpg and 0432.jpg, saved 430.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0436.jpg and 0440.jpg, saved 438.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0444.jpg and 0448.jpg, saved 446.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0452.jpg and 0456.jpg, saved 454.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0460.jpg and 0464.jpg, saved 462.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0468.jpg and 0472.jpg, saved 470.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0476.jpg and 0480.jpg, saved 478.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0484.jpg and 0488.jpg, saved 486.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0492.jpg and 0496.jpg, saved 494.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0500.jpg and 0504.jpg, saved 502.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0508.jpg and 0512.jpg, saved 510.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0516.jpg and 0520.jpg, saved 518.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0524.jpg and 0528.jpg, saved 526.png

# %%
# second iteration

input_folder = r"outputs"
output_folder = r"outputs2"
target_size = (256, 256)  # Resize frames to match the model's input size

# Interpolate frames using the loaded model
interpolate_frames(input_folder, output_folder, model, target_size)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0004.jpg and 006.png, saved 005.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0008.jpg and 0012.jpg, saved 010.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 014.png and 0016.jpg, saved 015.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0020.jpg and 022.png, saved 021.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0024.jpg and 0028.jpg, saved 026.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 030.png and 0032.jpg, saved 031.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0036.jpg and 038.png, saved 037.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0040.jpg and 0044.jpg, saved 042.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 046.png and 0048.jpg, saved 047.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0052.jpg and 054.png, saved 053.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0056.jpg and 0060.jpg, saved 058.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 062.png and 0064.jpg, saved 063.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0068.jpg and 070.png, saved 069.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0072.jpg and 0076.jpg, saved 074.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 078.png and 0080.jpg, saved 079.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0084.jpg and 086.png, saved 085.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0088.jpg and 0092.jpg, saved 090.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 094.png and 0096.jpg, saved 095.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0100.jpg and 102.png, saved 101.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0104.jpg and 0108.jpg, saved 106.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 110.png and 0112.jpg, saved 111.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0116.jpg and 118.png, saved 117.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0120.jpg and 0124.jpg, saved 122.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 126.png and 0128.jpg, saved 127.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0132.jpg and 134.png, saved 133.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0136.jpg and 0140.jpg, saved 138.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 142.png and 0144.jpg, saved 143.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0148.jpg and 150.png, saved 149.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0152.jpg and 0156.jpg, saved 154.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 158.png and 0160.jpg, saved 159.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0164.jpg and 166.png, saved 165.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0168.jpg and 0172.jpg, saved 170.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 174.png and 0176.jpg, saved 175.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0180.jpg and 182.png, saved 181.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0184.jpg and 0188.jpg, saved 186.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 190.png and 0192.jpg, saved 191.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0196.jpg and 198.png, saved 197.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0200.jpg and 0204.jpg, saved 202.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 206.png and 0208.jpg, saved 207.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0212.jpg and 214.png, saved 213.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0216.jpg and 0220.jpg, saved 218.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 222.png and 0224.jpg, saved 223.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0228.jpg and 230.png, saved 229.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0232.jpg and 0236.jpg, saved 234.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 238.png and 0240.jpg, saved 239.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0244.jpg and 246.png, saved 245.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0248.jpg and 0252.jpg, saved 250.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 254.png and 0256.jpg, saved 255.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0260.jpg and 262.png, saved 261.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Processed frames 0264.jpg and 0268.jpg, saved 266.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step

# %%
import cv2
import os

def images_to_video(image_folder, output_video_path, fps):
    """
    Combines images from a folder into a video.
    
    Args:
        image_folder (str): Path to the folder containing images.
        output_video_path (str): Path to save the output video file.
        fps (int): Frames per second for the output video.
    """
    # Get all image files in the folder, sorted by name
    image_files = sorted(
        [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))],
        key=lambda x: int(os.path.splitext(x)[0])  # Sort numerically based on filename
    )

    if not image_files:
        print("No images found in the specified folder.")
        return

    # Read the first image to get the dimensions
    first_image_path = os.path.join(image_folder, image_files[0])
    first_image = cv2.imread(first_image_path)
    height, width, _ = first_image.shape

    # Define the video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
    video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

    # Write each image to the video
    for image_file in image_files:
        image_path = os.path.join(image_folder, image_file)
        image = cv2.imread(image_path)
        if image is None:
            print(f"Warning: Unable to read {image_file}. Skipping.")
            continue
        video_writer.write(image)

    # Release the video writer
    video_writer.release()
    print(f"Video saved to {output_video_path}")

# Example usage
image_folder = r"outputs2"  # Path to the folder containing images
output_video_path = r"output_video.mp4"  # Path to save the output video
fps = 30  # Frames per second

images_to_video(image_folder, output_video_path, fps)
# Out:
# Video saved to output_video.mp4
